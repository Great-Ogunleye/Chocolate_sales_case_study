# %% [markdown]
# Data download

# %%
import pandas as pd
from pathlib import Path
import urllib.request
import zipfile

print("Downloading Chocolate Sales dataset")

url = "https://www.kaggle.com/api/v1/datasets/download/ssssws/chocolate-sales-dataset-2023-2024"

print("Download dataset")
output_path = Path("dataset\Rawdata")
output_path.mkdir(exist_ok=True)
zip_path = output_path/"dataset.zip"
print("Downloading in 2-5 minutes")

print("Data retrieval")
urllib.request.urlretrieve(url, zip_path)
print("Data retrieval complete")

print("Extracting files")
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(output_path)
print("Extraction complete")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\R'
# <>:11: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\ogunl\AppData\Local\Temp\ipykernel_5056\694379892.py:11: SyntaxWarning: invalid escape sequence '\R'
#   output_path = Path("dataset\Rawdata")
# ...
# Download dataset
# ...
# Data retrieval
# Data retrieval complete
# Extracting files
# Extraction complete
